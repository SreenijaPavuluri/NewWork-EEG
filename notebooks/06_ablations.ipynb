# %% [markdown]
# # 06 — Ablation Studies
#
# Runs all required ablation experiments.

# %%
# Run ablations (adjust n-subjects for CPU budget)
# !python ../scripts/ablation.py --n-subjects 15 --epochs 15

# %%
import pandas as pd
from pathlib import Path
from IPython.display import display

abl_path = Path('../results/tables/ablation_results.csv')
if abl_path.exists():
    df = pd.read_csv(abl_path)
    display(df.sort_values('accuracy', ascending=False))
else:
    print('Run ablation.py first')
