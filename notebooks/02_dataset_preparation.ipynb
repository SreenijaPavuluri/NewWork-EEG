# %% [markdown]
# # 02 — Dataset Preparation & Validation
#
# Downloads and validates PhysioNet EEGMMIDB.

# %%
import sys
sys.path.insert(0, '..')
from src.utils.logging_utils import setup_logging
setup_logging()

# Download first 5 subjects as verification
# !python ../scripts/download_data.py --dataset physionet --n-subjects 5

# %%
# Validate preprocessing
# !python ../scripts/validate_datasets.py --dataset physionet --n-subjects 5

# %%
# Display dataset report
from pathlib import Path
from IPython.display import Markdown
report_path = Path('../results/dataset_report.md')
if report_path.exists():
    Markdown(report_path.read_text())
else:
    print('Run download_data.py first')
