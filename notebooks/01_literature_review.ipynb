# %% [markdown]
# # 01 — Literature Review & Research Gap Analysis
#
# This notebook summarizes the structured literature review for STELLA.
# Full literature review: `paper/literature_review.md`
# Novelty analysis: `paper/novelty_analysis.md`

# %%
from pathlib import Path
from IPython.display import Markdown

lit_review = Path('../paper/literature_review.md').read_text()
Markdown(lit_review[:3000] + '\n\n*[truncated — see paper/literature_review.md for full text]*')

# %%
novelty = Path('../paper/novelty_analysis.md').read_text()
Markdown(novelty)

# %% [markdown]
# ## Selected Architecture: STELLA
#
# Based on the gap analysis, **STELLA (Spectro-Temporal EEG Learning with Latent Alignment)** was selected.
#
# Primary innovation axis: **dual-stream tokenization + gated spectral-temporal fusion**
#
# Supporting innovations:
# 1. CPU-native S3M (Selective State Space Module)
# 2. Subject-aware multi-objective pretraining
# 3. Topology-aware shallow channel Transformer
